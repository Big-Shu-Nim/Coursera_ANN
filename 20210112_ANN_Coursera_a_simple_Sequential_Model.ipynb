# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras   #  to build a neural network as a sequence of layers

print(tf.__version__) # To ckeck the version of TF
# Out:
# 2.7.0

# %%
# Build a simple Sequential model
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %% [markdown]
# The **loss function** measures the guessed answers against the known correct answers and measures how well or how badly it did.
#
# It then uses **the optimizer function** to make another guess. Based on how the loss function went, it will try to minimize the loss. At that point maybe it will come up with something like y=5x+5, which, while still pretty bad, is closer to the correct result

# %%
# 2 Compile the model
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# 3 Time to feed some datas
   # 3-2 Declare model inputs and outputs for training
xs= np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
# 4 Train the data with the model you made 

model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.7208
# Epoch 2/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6970
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6756
# Epoch 4/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.6561
# Epoch 5/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.6382
# Epoch 6/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.6217
# Epoch 7/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6062
# Epoch 8/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5916
# Epoch 9/500
# 1/1 [==============================] - 0s 16ms/step - loss: 0.5778
# Epoch 10/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5646
# Epoch 11/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5519
# Epoch 12/500
# 1/1 [==============================] - 0s 6ms/step - loss: 0.5398
# ...

# %%
# 5 Make a prediction
print(model.predict([10.0]))
# Out:
# [[19.013504]]

# %% [markdown]
# The predicted value should be under 19 but my predicted value a bit above 19.0. I had not idea why it hapeening.
